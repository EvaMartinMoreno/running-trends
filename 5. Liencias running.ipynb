# %% [markdown]
# # 5. Licencias de atletismo en España en el tiempo

# %% [markdown]
# Tenemos un csv con el numero de licencias en Atletismo en España (by CSD) durante un periodo de tiempo.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Load the data
df_licencias = pd.read_csv('historico-de-licencias.csv', sep=',')
print(df_licencias.head())
df_licencias.info()
df_licencias.describe()
# Out:
#                 Unnamed: 0                Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0  HISTÓRICO  DE LICENCIAS                       NaN        NaN        NaN
# 1                       nº                FEDERACIÓN        NaN       1941
# 2                        1  ACTIVIDADES SUBACUÁTICAS        NaN        NaN
# 3                        2               AERONÁUTICA        NaN        NaN
# 4                        3                   AJEDREZ        NaN        655
#
#   Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0        NaN         NaN        NaN        NaN         NaN         NaN  ...
# 1       1942      1943.0        NaN        NaN      1944.0         NaN  ...
# 2        NaN         NaN        NaN        NaN         NaN         NaN  ...
# 3        NaN         NaN        NaN        NaN         NaN         NaN  ...
# 4        710       790.0        NaN        NaN       940.0         NaN  ...
#
# ...
